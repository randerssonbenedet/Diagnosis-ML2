# %% [markdown]
# This project is about implementing machine learning algorithms to diagnose breast cancer. The dataset used in this project is from UCI ML Breast Cancer Wisconsin (Diagnostic). This project was done to be included in my ML portfolio.

# %% [markdown]
# # **Medical Diagnosis**
# In this project a logistic regression algorithm (as a baseline) and a neural network algorithm will be used to model the data. In this project, the diagnosis of breast cancer into malignant and benign tumours will be performed. To do so, a dataset is employed with several numeric features and attributes of the tissue. These features are computed from a digitized medical image of a breast mass.

# %% [markdown]
# Import TensorFlow

# %%
# Run on TensorFlow 2.x
# %tensorflow_version 2.x
from __future__ import absolute_import, division, print_function, unicode_literals
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# Import the necessary modules to prepare data etc.

# %%
#Import relevant modules
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# The following lines adjust the granularity of reporting.
pd.options.display.float_format = "{:.1f}".format

# %% [markdown]
# Load the dataset.

# %%
from sklearn.datasets import load_breast_cancer
df = load_breast_cancer()
dataset= pd.DataFrame(df['data'], columns=df['feature_names'])
dataset['target']= df['target']
dataset.columns = dataset.columns.str.replace(' ', '_')

# %% [markdown]
# First let's have a quick look at the dataset.

# %%
dataset.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0         18.0          10.4           122.8     1001.0              0.1
# 1         20.6          17.8           132.9     1326.0              0.1
# 2         19.7          21.2           130.0     1203.0              0.1
# 3         11.4          20.4            77.6      386.1              0.1
# 4         20.3          14.3           135.1     1297.0              0.1
#
#    mean_compactness  mean_concavity  mean_concave_points  mean_symmetry  \
# 0               0.3             0.3                  0.1            0.2
# 1               0.1             0.1                  0.1            0.2
# 2               0.2             0.2                  0.1            0.2
# 3               0.3             0.2                  0.1            0.3
# 4               0.1             0.2                  0.1            0.2
#
#    mean_fractal_dimension  ...  worst_texture  worst_perimeter  worst_area  \
# 0                     0.1  ...           17.3            184.6      2019.0
# 1                     0.1  ...           23.4            158.8      1956.0
# 2                     0.1  ...           25.5            152.5      1709.0
# 3                     0.1  ...           26.5             98.9       567.7
# 4                     0.1  ...           16.7            152.2      1575.0
#
#    worst_smoothness  worst_compactness  worst_concavity  worst_concave_points  \
# 0               0.2                0.7              0.7                   0.3
# 1               0.1                0.2              0.2                   0.2
# 2               0.1                0.4              0.5                   0.2
# 3               0.2                0.9              0.7                   0.3
# 4               0.1                0.2              0.4                   0.2
#
#    worst_symmetry  worst_fractal_dimension  target
# 0             0.5                      0.1       0
# 1             0.3                      0.1       0
# 2             0.4                      0.1       0
# 3             0.7                      0.2       0
# 4             0.2                      0.1       0
#
# [5 rows x 31 columns]

# %% [markdown]
# The statistics for the dataset is also good to have a look at.

# %%
dataset.describe()
# Out:
#        mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# count        569.0         569.0           569.0      569.0            569.0
# mean          14.1          19.3            92.0      654.9              0.1
# std            3.5           4.3            24.3      351.9              0.0
# min            7.0           9.7            43.8      143.5              0.1
# 25%           11.7          16.2            75.2      420.3              0.1
# 50%           13.4          18.8            86.2      551.1              0.1
# 75%           15.8          21.8           104.1      782.7              0.1
# max           28.1          39.3           188.5     2501.0              0.2
#
#        mean_compactness  mean_concavity  mean_concave_points  mean_symmetry  \
# count             569.0           569.0                569.0          569.0
# mean                0.1             0.1                  0.0            0.2
# std                 0.1             0.1                  0.0            0.0
# min                 0.0             0.0                  0.0            0.1
# 25%                 0.1             0.0                  0.0            0.2
# 50%                 0.1             0.1                  0.0            0.2
# 75%                 0.1             0.1                  0.1            0.2
# max                 0.3             0.4                  0.2            0.3
#
#        mean_fractal_dimension  ...  worst_texture  worst_perimeter  \
# count                   569.0  ...          569.0            569.0
# mean                      0.1  ...           25.7            107.3
# std                       0.0  ...            6.1             33.6
# min                       0.0  ...           12.0             50.4
# 25%                       0.1  ...           21.1             84.1
# 50%                       0.1  ...           25.4             97.7
# 75%                       0.1  ...           29.7            125.4
# max                       0.1  ...           49.5            251.2
#
#        worst_area  worst_smoothness  worst_compactness  worst_concavity  \
# count       569.0             569.0              569.0            569.0
# mean        880.6               0.1                0.3              0.3
# std         569.4               0.0                0.2              0.2
# min         185.2               0.1                0.0              0.0
# 25%         515.3               0.1                0.1              0.1
# 50%         686.5               0.1                0.2              0.2
# 75%        1084.0               0.1                0.3              0.4
# max        4254.0               0.2                1.1              1.3
#
#        worst_concave_points  worst_symmetry  worst_fractal_dimension  target
# count                 569.0           569.0                    569.0   569.0
# mean                    0.1             0.3                      0.1     0.6
# std                     0.1             0.1                      0.0     0.5
# min                     0.0             0.2                      0.1     0.0
# 25%                     0.1             0.3                      0.1     0.0
# 50%                     0.1             0.3                      0.1     1.0
# 75%                     0.2             0.3                      0.1     1.0
# max                     0.3             0.7                      0.2     1.0
#
# [8 rows x 31 columns]

# %% [markdown]
# Before beginning with the modeling it's good practice to find the biggest correlations between features so that the dataset can be understood better.

# %%
dataset.corr(method='pearson')
# Out:
#                          mean_radius  mean_texture  mean_perimeter  mean_area  \
# mean_radius                      1.0           0.3             1.0        1.0
# mean_texture                     0.3           1.0             0.3        0.3
# mean_perimeter                   1.0           0.3             1.0        1.0
# mean_area                        1.0           0.3             1.0        1.0
# mean_smoothness                  0.2          -0.0             0.2        0.2
# mean_compactness                 0.5           0.2             0.6        0.5
# mean_concavity                   0.7           0.3             0.7        0.7
# mean_concave_points              0.8           0.3             0.9        0.8
# mean_symmetry                    0.1           0.1             0.2        0.2
# mean_fractal_dimension          -0.3          -0.1            -0.3       -0.3
# radius_error                     0.7           0.3             0.7        0.7
# texture_error                   -0.1           0.4            -0.1       -0.1
# perimeter_error                  0.7           0.3             0.7        0.7
# area_error                       0.7           0.3             0.7        0.8
# smoothness_error                -0.2           0.0            -0.2       -0.2
# compactness_error                0.2           0.2             0.3        0.2
# concavity_error                  0.2           0.1             0.2        0.2
# concave_points_error             0.4           0.2             0.4        0.4
# symmetry_error                  -0.1           0.0            -0.1       -0.1
# fractal_dimension_error         -0.0           0.1            -0.0       -0.0
# worst_radius                     1.0           0.4             1.0        1.0
# worst_texture                    0.3           0.9             0.3        0.3
# worst_perimeter                  1.0           0.4             1.0        1.0
# worst_area                       0.9           0.3             0.9        1.0
# worst_smoothness                 0.1           0.1             0.2        0.1
# worst_compactness                0.4           0.3             0.5        0.4
# worst_concavity                  0.5           0.3             0.6        0.5
# worst_concave_points             0.7           0.3             0.8        0.7
# worst_symmetry                   0.2           0.1             0.2        0.1
# worst_fractal_dimension          0.0           0.1             0.1        0.0
# target                          -0.7          -0.4            -0.7       -0.7
#
#                          mean_smoothness  mean_compactness  mean_concavity  \
# mean_radius                          0.2               0.5             0.7
# mean_texture                        -0.0               0.2             0.3
# mean_perimeter                       0.2               0.6             0.7
# mean_area                            0.2               0.5             0.7
# mean_smoothness                      1.0               0.7             0.5
# mean_compactness                     0.7               1.0             0.9
# mean_concavity                       0.5               0.9             1.0
# mean_concave_points                  0.6               0.8             0.9
# mean_symmetry                        0.6               0.6             0.5
# mean_fractal_dimension               0.6               0.6             0.3
# radius_error                         0.3               0.5             0.6
# texture_error                        0.1               0.0             0.1
# perimeter_error                      0.3               0.5             0.7
# area_error                           0.2               0.5             0.6
# smoothness_error                     0.3               0.1             0.1
# compactness_error                    0.3               0.7             0.7
# concavity_error                      0.2               0.6             0.7
# concave_points_error                 0.4               0.6             0.7
# symmetry_error                       0.2               0.2             0.2
# fractal_dimension_error              0.3               0.5             0.4
# worst_radius                         0.2               0.5             0.7
# worst_texture                        0.0               0.2             0.3
# worst_perimeter                      0.2               0.6             0.7
# worst_area                           0.2               0.5             0.7
# worst_smoothness                     0.8               0.6             0.4
# worst_compactness                    0.5               0.9             0.8
# worst_concavity                      0.4               0.8             0.9
# worst_concave_points                 0.5               0.8             0.9
# worst_symmetry                       0.4               0.5             0.4
# worst_fractal_dimension              0.5               0.7             0.5
# target                              -0.4              -0.6            -0.7
#
#                          mean_concave_points  mean_symmetry  \
# mean_radius                              0.8            0.1
# mean_texture                             0.3            0.1
# mean_perimeter                           0.9            0.2
# mean_area                                0.8            0.2
# mean_smoothness                          0.6            0.6
# mean_compactness                         0.8            0.6
# mean_concavity                           0.9            0.5
# mean_concave_points                      1.0            0.5
# mean_symmetry                            0.5            1.0
# mean_fractal_dimension                   0.2            0.5
# radius_error                             0.7            0.3
# texture_error                            0.0            0.1
# perimeter_error                          0.7            0.3
# area_error                               0.7            0.2
# smoothness_error                         0.0            0.2
# compactness_error                        0.5            0.4
# concavity_error                          0.4            0.3
# concave_points_error                     0.6            0.4
# symmetry_error                           0.1            0.4
# fractal_dimension_error                  0.3            0.3
# worst_radius                             0.8            0.2
# worst_texture                            0.3            0.1
# worst_perimeter                          0.9            0.2
# worst_area                               0.8            0.2
# worst_smoothness                         0.5            0.4
# worst_compactness                        0.7            0.5
# worst_concavity                          0.8            0.4
# worst_concave_points                     0.9            0.4
# worst_symmetry                           0.4            0.7
# worst_fractal_dimension                  0.4            0.4
# target                                  -0.8           -0.3
#
#                          mean_fractal_dimension  ...  worst_texture  \
# mean_radius                                -0.3  ...            0.3
# mean_texture                               -0.1  ...            0.9
# mean_perimeter                             -0.3  ...            0.3
# mean_area                                  -0.3  ...            0.3
# mean_smoothness                             0.6  ...            0.0
# mean_compactness                            0.6  ...            0.2
# mean_concavity                              0.3  ...            0.3
# mean_concave_points                         0.2  ...            0.3
# mean_symmetry                               0.5  ...            0.1
# mean_fractal_dimension                      1.0  ...           -0.1
# radius_error                                0.0  ...            0.2
# texture_error                               0.2  ...            0.4
# perimeter_error                             0.0  ...            0.2
# area_error                                 -0.1  ...            0.2
# smoothness_error                            0.4  ...           -0.1
# compactness_error                           0.6  ...            0.1
# concavity_error                             0.4  ...            0.1
# concave_points_error                        0.3  ...            0.1
# symmetry_error                              0.3  ...           -0.1
# fractal_dimension_error                     0.7  ...           -0.0
# worst_radius                               -0.3  ...            0.4
# worst_texture                              -0.1  ...            1.0
# worst_perimeter                            -0.2  ...            0.4
# worst_area                                 -0.2  ...            0.3
# worst_smoothness                            0.5  ...            0.2
# worst_compactness                           0.5  ...            0.4
# worst_concavity                             0.3  ...            0.4
# worst_concave_points                        0.2  ...            0.4
# worst_symmetry                              0.3  ...            0.2
# worst_fractal_dimension                     0.8  ...            0.2
# target                                      0.0  ...           -0.5
#
#                          worst_perimeter  worst_area  worst_smoothness  \
# mean_radius                          1.0         0.9               0.1
# mean_texture                         0.4         0.3               0.1
# mean_perimeter                       1.0         0.9               0.2
# mean_area                            1.0         1.0               0.1
# mean_smoothness                      0.2         0.2               0.8
# mean_compactness                     0.6         0.5               0.6
# mean_concavity                       0.7         0.7               0.4
# mean_concave_points                  0.9         0.8               0.5
# mean_symmetry                        0.2         0.2               0.4
# mean_fractal_dimension              -0.2        -0.2               0.5
# radius_error                         0.7         0.8               0.1
# texture_error                       -0.1        -0.1              -0.1
# perimeter_error                      0.7         0.7               0.1
# area_error                           0.8         0.8               0.1
# smoothness_error                    -0.2        -0.2               0.3
# compactness_error                    0.3         0.2               0.2
# concavity_error                      0.2         0.2               0.2
# concave_points_error                 0.4         0.3               0.2
# symmetry_error                      -0.1        -0.1              -0.0
# fractal_dimension_error             -0.0        -0.0               0.2
# worst_radius                         1.0         1.0               0.2
# worst_texture                        0.4         0.3               0.2
# worst_perimeter                      1.0         1.0               0.2
# worst_area                           1.0         1.0               0.2
# worst_smoothness                     0.2         0.2               1.0
# worst_compactness                    0.5         0.4               0.6
# worst_concavity                      0.6         0.5               0.5
# worst_concave_points                 0.8         0.7               0.5
# worst_symmetry                       0.3         0.2               0.5
# worst_fractal_dimension              0.1         0.1               0.6
# target                              -0.8        -0.7              -0.4
#
#                          worst_compactness  worst_concavity  \
# mean_radius                            0.4              0.5
# mean_texture                           0.3              0.3
# mean_perimeter                         0.5              0.6
# mean_area                              0.4              0.5
# mean_smoothness                        0.5              0.4
# mean_compactness                       0.9              0.8
# mean_concavity                         0.8              0.9
# mean_concave_points                    0.7              0.8
# mean_symmetry                          0.5              0.4
# mean_fractal_dimension                 0.5              0.3
# radius_error                           0.3              0.4
# texture_error                         -0.1             -0.1
# perimeter_error                        0.3              0.4
# area_error                             0.3              0.4
# smoothness_error                      -0.1             -0.1
# compactness_error                      0.7              0.6
# concavity_error                        0.5              0.7
# concave_points_error                   0.5              0.5
# symmetry_error                         0.1              0.0
# fractal_dimension_error                0.4              0.4
# worst_radius                           0.5              0.6
# worst_texture                          0.4              0.4
# worst_perimeter                        0.5              0.6
# worst_area                             0.4              0.5
# worst_smoothness                       0.6              0.5
# worst_compactness                      1.0              0.9
# worst_concavity                        0.9              1.0
# worst_concave_points                   0.8              0.9
# worst_symmetry                         0.6              0.5
# worst_fractal_dimension                0.8              0.7
# target                                -0.6             -0.7
#
#                          worst_concave_points  worst_symmetry  \
# mean_radius                               0.7             0.2
# mean_texture                              0.3             0.1
# mean_perimeter                            0.8             0.2
# mean_area                                 0.7             0.1
# mean_smoothness                           0.5             0.4
# mean_compactness                          0.8             0.5
# mean_concavity                            0.9             0.4
# mean_concave_points                       0.9             0.4
# mean_symmetry                             0.4             0.7
# mean_fractal_dimension                    0.2             0.3
# radius_error                              0.5             0.1
# texture_error                            -0.1            -0.1
# perimeter_error                           0.6             0.1
# area_error                                0.5             0.1
# smoothness_error                         -0.1            -0.1
# compactness_error                         0.5             0.3
# concavity_error                           0.4             0.2
# concave_points_error                      0.6             0.1
# symmetry_error                           -0.0             0.4
# fractal_dimension_error                   0.2             0.1
# worst_radius                              0.8             0.2
# worst_texture                             0.4             0.2
# worst_perimeter                           0.8             0.3
# worst_area                                0.7             0.2
# worst_smoothness                          0.5             0.5
# worst_compactness                         0.8             0.6
# worst_concavity                           0.9             0.5
# worst_concave_points                      1.0             0.5
# worst_symmetry                            0.5             1.0
# worst_fractal_dimension                   0.5             0.5
# target                                   -0.8            -0.4
#
#                          worst_fractal_dimension  target
# mean_radius                                  0.0    -0.7
# mean_texture                                 0.1    -0.4
# mean_perimeter                               0.1    -0.7
# mean_area                                    0.0    -0.7
# mean_smoothness                              0.5    -0.4
# mean_compactness                             0.7    -0.6
# mean_concavity                               0.5    -0.7
# mean_concave_points                          0.4    -0.8
# mean_symmetry                                0.4    -0.3
# mean_fractal_dimension                       0.8     0.0
# radius_error                                 0.0    -0.6
# texture_error                               -0.0     0.0
# perimeter_error                              0.1    -0.6
# area_error                                   0.0    -0.5
# smoothness_error                             0.1     0.1
# compactness_error                            0.6    -0.3
# concavity_error                              0.4    -0.3
# concave_points_error                         0.3    -0.4
# symmetry_error                               0.1     0.0
# fractal_dimension_error                      0.6    -0.1
# worst_radius                                 0.1    -0.8
# worst_texture                                0.2    -0.5
# worst_perimeter                              0.1    -0.8
# worst_area                                   0.1    -0.7
# worst_smoothness                             0.6    -0.4
# worst_compactness                            0.8    -0.6
# worst_concavity                              0.7    -0.7
# worst_concave_points                         0.5    -0.8
# worst_symmetry                               0.5    -0.4
# worst_fractal_dimension                      1.0    -0.3
# target                                      -0.3     1.0
#
# [31 rows x 31 columns]

# %% [markdown]
# ## Dataset preparation
# Here the dataset will be split into the input features and the output target. For the input features, select the top 4 features with highest correlations to the target. The four features with the highest correlation to the target are: mean_area, mean_radius, mean_perimeter, and mean_concave_points.

# %%
y_dataset = dataset.pop('target')
X_dataset = dataset[['mean_area', 'mean_radius', 'mean_perimeter', 'mean_concave_points']]

# %% [markdown]
# The features are normalized using Z-score to be easier to work with.

# %%
X_dataset_mean = X_dataset.mean()
X_dataset_std = X_dataset.std()
X_dataset_norm = (X_dataset - X_dataset_mean)/X_dataset_std
# Out:
# Dataset normalized.

# %% [markdown]
# Now it is appropriate to split the dataset into a training set and a test set, since we now have all the features normalized. 80/20 split works well for this project. Random state will be set to 100 for reproducibility.

# %%
from sklearn.model_selection import train_test_split
X_train_norm, X_test_norm, y_train, y_test = train_test_split(X_dataset_norm , y_dataset , test_size=0.2 , random_state=100)
# Out:
# Dataset split.

# %% [markdown]
# ## Logistic regression
# A logistic regression model can be used as the baseline. Here we define and train a logistic regression model.

# %% [markdown]
# **Question 5:** Train the initialized model using the training data.

# %%
# Create a logistic regression object and train it

model_LR = LogisticRegression()
model_LR.fit(X_train_norm, y_train)
y_predict_LR = model_LR.predict(X_test_norm)

# %% [markdown]
# Now we evaluate the performance of the LR model using the test set. Mean square error is an appropriate metric to judge the model by.

# %%
# Evaluate the trained model against the test set.

print("\n Evaluate the logistic regression model against the test set:")
accuracy_score(y_predict_LR, y_test)
# Out:
#  Evaluate the logistic regression model against the test set:
# 0.9210526315789473

# %% [markdown]
# ## Neural network
# Now the neural network will be defined. For this we will try using three hidden layers with 16, 8, and 6 nodes. The activation function will be set to relu and the kernel_regularizer as l2, l=0.001.

# %%
# Find the number of input features
n_features = X_train_norm.shape[1]

# Create the neural network
model_NN = tf.keras.Sequential([
    layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.001), input_shape=(n_features,)),
    layers.Dense(8, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.001)),
    layers.Dense(6, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.001)),
    layers.Dense(1, activation='sigmoid')
])

# %% [markdown]
# The neural network model should trained using the training data. Here we set the number of epochs(100), the optimization algorithm('adam'), and loss function(BCE).

# %%
# compile the model
#model_NN.compile(optimizer='adam', loss='mse', metrics=['mse'])
model_NN.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# Fit the model
model_NN.fit(x=X_train_norm, y=y_train, epochs=100)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 6ms/step - loss: 0.6679 - binary_accuracy: 0.6835
# Epoch 2/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5908 - binary_accuracy: 0.6637
# Epoch 3/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5316 - binary_accuracy: 0.6549
# Epoch 4/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4830 - binary_accuracy: 0.6857
# Epoch 5/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4457 - binary_accuracy: 0.7802
# Epoch 6/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4088 - binary_accuracy: 0.8593
# Epoch 7/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3708 - binary_accuracy: 0.9033
# Epoch 8/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3353 - binary_accuracy: 0.9143
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3034 - binary_accuracy: 0.9055
# Epoch 10/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2787 - binary_accuracy: 0.9077
# Epoch 11/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2604 - binary_accuracy: 0.9121
# Epoch 12/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2456 - binary_accuracy: 0.9165
# Epoch 13/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2368 - binary_accuracy: 0.9187
# Epoch 14/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2298 - binary_accuracy: 0.9253
# Epoch 15/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2254 - binary_accuracy: 0.9275
# Epoch 16/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2222 - binary_accuracy: 0.9231
# Epoch 17/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2193 - binary_accuracy: 0.9253
# Epoch 18/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2173 - binary_accuracy: 0.9253
# Epoch 19/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2157 - binary_accuracy: 0.9231
# Epoch 20/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2145 - binary_accuracy: 0.9209
# Epoch 21/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2137 - binary_accuracy: 0.9209
# Epoch 22/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2125 - binary_accuracy: 0.9209
# Epoch 23/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2129 - binary_accuracy: 0.9209
# Epoch 24/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2120 - binary_accuracy: 0.9231
# Epoch 25/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2115 - binary_accuracy: 0.9253
# Epoch 26/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2110 - binary_accuracy: 0.9253
# Epoch 27/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2102 - binary_accuracy: 0.9209
# Epoch 28/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2100 - binary_accuracy: 0.9209
# Epoch 29/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2098 - binary_accuracy: 0.9209
# Epoch 30/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2091 - binary_accuracy: 0.9209
# Epoch 31/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2087 - binary_accuracy: 0.9209
# Epoch 32/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2083 - binary_accuracy: 0.9187
# Epoch 33/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2083 - binary_accuracy: 0.9187
# Epoch 34/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2073 - binary_accuracy: 0.9165
# Epoch 35/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2072 - binary_accuracy: 0.9209
# Epoch 36/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2074 - binary_accuracy: 0.9231
# Epoch 37/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2071 - binary_accuracy: 0.9209
# Epoch 38/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2066 - binary_accuracy: 0.9209
# Epoch 39/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2061 - binary_accuracy: 0.9187
# Epoch 40/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2055 - binary_accuracy: 0.9209
# Epoch 41/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2057 - binary_accuracy: 0.9209
# Epoch 42/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2050 - binary_accuracy: 0.9187
# Epoch 43/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2049 - binary_accuracy: 0.9187
# Epoch 44/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2044 - binary_accuracy: 0.9187
# Epoch 45/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2049 - binary_accuracy: 0.9209
# Epoch 46/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2041 - binary_accuracy: 0.9187
# Epoch 47/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2039 - binary_accuracy: 0.9231
# Epoch 48/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2037 - binary_accuracy: 0.9209
# Epoch 49/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2035 - binary_accuracy: 0.9209
# Epoch 50/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2030 - binary_accuracy: 0.9187
# Epoch 51/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2035 - binary_accuracy: 0.9209
# Epoch 52/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2027 - binary_accuracy: 0.9209
# Epoch 53/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2023 - binary_accuracy: 0.9187
# Epoch 54/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2025 - binary_accuracy: 0.9165
# Epoch 55/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2018 - binary_accuracy: 0.9165
# Epoch 56/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2019 - binary_accuracy: 0.9187
# Epoch 57/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2022 - binary_accuracy: 0.9187
# Epoch 58/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2020 - binary_accuracy: 0.9209
# Epoch 59/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2014 - binary_accuracy: 0.9187
# Epoch 60/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2015 - binary_accuracy: 0.9187
# Epoch 61/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2009 - binary_accuracy: 0.9187
# Epoch 62/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2006 - binary_accuracy: 0.9165
# Epoch 63/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2010 - binary_accuracy: 0.9165
# Epoch 64/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2006 - binary_accuracy: 0.9187
# Epoch 65/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2008 - binary_accuracy: 0.9209
# Epoch 66/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2007 - binary_accuracy: 0.9209
# Epoch 67/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2005 - binary_accuracy: 0.9165
# Epoch 68/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1998 - binary_accuracy: 0.9165
# Epoch 69/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1995 - binary_accuracy: 0.9187
# Epoch 70/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1995 - binary_accuracy: 0.9209
# Epoch 71/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1993 - binary_accuracy: 0.9209
# Epoch 72/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1992 - binary_accuracy: 0.9187
# Epoch 73/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1991 - binary_accuracy: 0.9165
# Epoch 74/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1989 - binary_accuracy: 0.9165
# Epoch 75/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1993 - binary_accuracy: 0.9187
# Epoch 76/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1989 - binary_accuracy: 0.9209
# Epoch 77/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1991 - binary_accuracy: 0.9209
# Epoch 78/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1994 - binary_accuracy: 0.9165
# Epoch 79/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1986 - binary_accuracy: 0.9187
# Epoch 80/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1981 - binary_accuracy: 0.9187
# Epoch 81/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1984 - binary_accuracy: 0.9187
# Epoch 82/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1981 - binary_accuracy: 0.9187
# Epoch 83/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1985 - binary_accuracy: 0.9187
# Epoch 84/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1977 - binary_accuracy: 0.9165
# Epoch 85/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1978 - binary_accuracy: 0.9187
# Epoch 86/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1972 - binary_accuracy: 0.9209
# Epoch 87/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1977 - binary_accuracy: 0.9187
# Epoch 88/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1974 - binary_accuracy: 0.9209
# Epoch 89/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1974 - binary_accuracy: 0.9209
# Epoch 90/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1974 - binary_accuracy: 0.9231
# Epoch 91/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1968 - binary_accuracy: 0.9209
# Epoch 92/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1966 - binary_accuracy: 0.9209
# Epoch 93/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1964 - binary_accuracy: 0.9231
# Epoch 94/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1964 - binary_accuracy: 0.9231
# Epoch 95/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1964 - binary_accuracy: 0.9209
# Epoch 96/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1962 - binary_accuracy: 0.9231
# Epoch 97/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1961 - binary_accuracy: 0.9209
# Epoch 98/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1965 - binary_accuracy: 0.9231
# Epoch 99/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1966 - binary_accuracy: 0.9253
# Epoch 100/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1964 - binary_accuracy: 0.9253

# %% [markdown]
# Now the performance will be evaluated.

# %%
# Evaluate the trained model against the test set.
print("\n Evaluate the neural network model against the test set:")
model_NN.evaluate(x = X_test_norm, y = y_test)
# Out:
#  Evaluate the neural network model against the test set:
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1927 - binary_accuracy: 0.9123
# [0.19265033304691315, 0.9122806787490845]

# %%
# Evaluate the trained model against the test set.
print("\n Evaluate the neural network model against the test set:")
model_NN.evaluate(x = X_test_norm, y = y_test)

print("\n Evaluate the logistic regression model against the test set:")
accuracy_score(y_predict_LR, y_test)


# Compute mean squared error
mse_nn = model_NN.evaluate(X_test_norm, y_test)
print("Mean Squared Error of the Neural Network: ",mse_nn)

mse_lr = mean_squared_error(y_test, y_predict_LR)
print("Mean Squared Error of the Logistic Regression: ", mse_lr)

# Compute mean squared error
mse_nn = model_NN.evaluate(X_train_norm, y_train)
print("Mean Squared Error of the Neural Network: ",mse_nn)

y_predict_train = model_LR.predict(X_train_norm)
mse_lr = mean_squared_error(y_train, y_predict_train)
print("Mean Squared Error of the Logistic Regression: ", mse_lr)
# Out:
#  Evaluate the neural network model against the test set:
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1927 - binary_accuracy: 0.9123
#
#  Evaluate the logistic regression model against the test set:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1927 - binary_accuracy: 0.9123
# Mean Squared Error of the Neural Network:  [0.19265033304691315, 0.9122806787490845]
# Mean Squared Error of the Logistic Regression:  0.07894736842105263
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1955 - binary_accuracy: 0.9231
# Mean Squared Error of the Neural Network:  [0.19548872113227844, 0.9230769276618958]
# Mean Squared Error of the Logistic Regression:  0.08791208791208792

# %% [markdown]
# Accuracy LR: 0.9210526315789473
# Accuracy NN: 0.9210526347160339
# MSE LR test: 0.07894736842105263
# MSE NN test: 0.054480426013469696
# MSE LR train: 0.08791208791208792
# MSE NN train: 0.05716453865170479
# To get these values I added the code in question 10, and I also had to modify the compiler for the NN to get MSE. As can be seen above the models are very similar in accuracy and MSE. Since the NN has a higher accuracy and a lower MSE in both the training and test data it is the better model. The MSE is also very similar between the test and training data so the overfitting can be said to be minimal. When evaluating models it is also important to take the time to execute into account, and in this case the logistic model is much faster. The NN is still the better model in this case I would say, since it will probably get better the more data provided. Although it will also take more time to compute.
